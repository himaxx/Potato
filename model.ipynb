# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import os
import matplotlib.image as mpimg
import random
from sklearn import preprocessing
import tensorflow.keras as keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From c:\Users\ha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## adding some static variable

# %%
SIZE = 256
SEED_TRAINING = 121
SEED_TESTING = 197
SEED_VALIDATION = 164
CHANNELS = 3
n_classes = 3
EPOCHS = 50
BATCH_SIZE = 16
input_shape = (SIZE, SIZE, CHANNELS)

# %%
train_datagen = ImageDataGenerator(
        rescale = 1./255,
        rotation_range = 30,
        shear_range = 0.2,
        zoom_range = 0.2,
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip = True,
        fill_mode = 'nearest')

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        directory = 'Potato Plant Dataset/train',  # this is the input directory
        target_size = (256, 256),  # all images will be resized to 64x64
        batch_size = BATCH_SIZE,
        class_mode = 'categorical',
        color_mode="rgb")
# Out:
# Found 692 images belonging to 3 classes.

# %%
validation_generator = validation_datagen.flow_from_directory(
        'Potato Plant Dataset/valid',
        target_size = (256, 256),
        batch_size = BATCH_SIZE,
        class_mode='categorical',
        color_mode="rgb")
# Out:
# Found 80 images belonging to 3 classes.

# %%
test_generator = test_datagen.flow_from_directory(
        'Potato Plant Dataset/test',
        target_size = (256, 256),
        batch_size = BATCH_SIZE,
        class_mode = 'categorical',
        color_mode = "rgb"
)
# Out:
# Found 160 images belonging to 3 classes.

# %%
model = keras.models.Sequential([
        keras.layers.Conv2D(32, (3,3), activation = 'relu', input_shape = input_shape),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Dropout(0.5),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Dropout(0.5),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Flatten(),
        keras.layers.Dense(32, activation ='relu'),
        keras.layers.Dense(n_classes, activation='softmax')
    ])
# Out:
# WARNING:tensorflow:From c:\Users\ha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\ha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  dropout (Dropout)           (None, 127, 127, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 127, 127, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 63, 63, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 63, 63, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 63, 63, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 31, 31, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 31, 31, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPoolin  (None, 3, 3, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 32)                18464
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 185667 (725.26 KB)
# Trainable params: 185667 (725.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.CategoricalCrossentropy(),
    metrics  = ['accuracy']
    )
# Out:
# WARNING:tensorflow:From c:\Users\ha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit_generator(
        train_generator,
        steps_per_epoch = train_generator.n // train_generator.batch_size,    #The 2 slashes division return rounded integer
        epochs = EPOCHS,
        validation_data = validation_generator,
        validation_steps = validation_generator.n // validation_generator.batch_size
        )
# Out:
# C:\Users\ha\AppData\Local\Temp\ipykernel_12868\2547534726.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\ha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 43/43 [==============================] - 42s 879ms/step - loss: 1.0918 - accuracy: 0.3787 - val_loss: 1.0956 - val_accuracy: 0.2500
# Epoch 2/50
# 43/43 [==============================] - 33s 742ms/step - loss: 1.0381 - accuracy: 0.5148 - val_loss: 1.1084 - val_accuracy: 0.2500
# Epoch 3/50
# 43/43 [==============================] - 32s 729ms/step - loss: 0.8605 - accuracy: 0.5636 - val_loss: 0.9963 - val_accuracy: 0.5375
# Epoch 4/50
# 43/43 [==============================] - 29s 670ms/step - loss: 0.6155 - accuracy: 0.7189 - val_loss: 1.1381 - val_accuracy: 0.3750
# Epoch 5/50
# 43/43 [==============================] - 28s 656ms/step - loss: 0.5169 - accuracy: 0.7751 - val_loss: 0.8088 - val_accuracy: 0.6250
# Epoch 6/50
# 43/43 [==============================] - 30s 675ms/step - loss: 0.3862 - accuracy: 0.8240 - val_loss: 0.5268 - val_accuracy: 0.7625
# Epoch 7/50
# 43/43 [==============================] - 26s 602ms/step - loss: 0.2956 - accuracy: 0.8787 - val_loss: 0.7428 - val_accuracy: 0.5875
# Epoch 8/50
# 43/43 [==============================] - 27s 631ms/step - loss: 0.2938 - accuracy: 0.8595 - val_loss: 0.4892 - val_accuracy: 0.7250
# Epoch 9/50
# 43/43 [==============================] - 34s 783ms/step - loss: 0.2926 - accuracy: 0.8802 - val_loss: 0.7576 - val_accuracy: 0.6125
# Epoch 10/50
# 43/43 [==============================] - 42s 969ms/step - loss: 0.2584 - accuracy: 0.8846 - val_loss: 0.4230 - val_accuracy: 0.8000
# Epoch 11/50
# 43/43 [==============================] - 36s 835ms/step - loss: 0.2707 - accuracy: 0.8772 - val_loss: 0.2839 - val_accuracy: 0.8875
# Epoch 12/50
# 43/43 [==============================] - 31s 720ms/step - loss: 0.2648 - accuracy: 0.8950 - val_loss: 0.4390 - val_accuracy: 0.8125
# Epoch 13/50
# 43/43 [==============================] - 32s 725ms/step - loss: 0.2492 - accuracy: 0.8994 - val_loss: 0.3819 - val_accuracy: 0.8500
# Epoch 14/50
# 43/43 [==============================] - 31s 714ms/step - loss: 0.2316 - accuracy: 0.9024 - val_loss: 0.3610 - val_accuracy: 0.7875
# Epoch 15/50
# 43/43 [==============================] - 32s 729ms/step - loss: 0.2036 - accuracy: 0.9231 - val_loss: 0.4210 - val_accuracy: 0.8250
# Epoch 16/50
# 43/43 [==============================] - 35s 807ms/step - loss: 0.2121 - accuracy: 0.9260 - val_loss: 0.4630 - val_accuracy: 0.8000
# Epoch 17/50
# 43/43 [==============================] - 33s 758ms/step - loss: 0.1325 - accuracy: 0.9408 - val_loss: 0.3486 - val_accuracy: 0.9000
# Epoch 36/50
# 43/43 [==============================] - 33s 761ms/step - loss: 0.1180 - accuracy: 0.9467 - val_loss: 0.1724 - val_accuracy: 0.9250
# Epoch 37/50
# 43/43 [==============================] - 34s 777ms/step - loss: 0.1442 - accuracy: 0.9364 - val_loss: 0.1803 - val_accuracy: 0.9125
# Epoch 38/50
# 43/43 [==============================] - 37s 864ms/step - loss: 0.1071 - accuracy: 0.9541 - val_loss: 0.3003 - val_accuracy: 0.8750
# Epoch 39/50
# 43/43 [==============================] - 34s 792ms/step - loss: 0.1123 - accuracy: 0.9467 - val_loss: 0.1537 - val_accuracy: 0.9125
# Epoch 40/50
# 43/43 [==============================] - 34s 792ms/step - loss: 0.1073 - accuracy: 0.9556 - val_loss: 0.1360 - val_accuracy: 0.9500
# Epoch 41/50
# 43/43 [==============================] - 35s 798ms/step - loss: 0.1121 - accuracy: 0.9512 - val_loss: 0.2285 - val_accuracy: 0.9000
# Epoch 42/50
# 43/43 [==============================] - 35s 795ms/step - loss: 0.1373 - accuracy: 0.9527 - val_loss: 0.1902 - val_accuracy: 0.9375
# Epoch 43/50
# 43/43 [==============================] - 34s 788ms/step - loss: 0.1260 - accuracy: 0.9467 - val_loss: 0.2163 - val_accuracy: 0.9125
# Epoch 44/50
# 43/43 [==============================] - 34s 786ms/step - loss: 0.1093 - accuracy: 0.9630 - val_loss: 0.1624 - val_accuracy: 0.9250
# Epoch 45/50
# 43/43 [==============================] - 35s 808ms/step - loss: 0.1089 - accuracy: 0.9556 - val_loss: 0.1875 - val_accuracy: 0.9250
# Epoch 46/50
# 43/43 [==============================] - 51s 1s/step - loss: 0.0766 - accuracy: 0.9734 - val_loss: 0.1186 - val_accuracy: 0.9500
# Epoch 47/50
# 43/43 [==============================] - 39s 918ms/step - loss: 0.0840 - accuracy: 0.9675 - val_loss: 0.3342 - val_accuracy: 0.8875
# Epoch 48/50
# 43/43 [==============================] - 40s 935ms/step - loss: 0.1187 - accuracy: 0.9497 - val_loss: 0.1274 - val_accuracy: 0.9375
# Epoch 49/50
# 43/43 [==============================] - 38s 887ms/step - loss: 0.1039 - accuracy: 0.9615 - val_loss: 0.0886 - val_accuracy: 0.9750
# Epoch 50/50
# 43/43 [==============================] - 43s 985ms/step - loss: 0.1150 - accuracy: 0.9512 - val_loss: 0.1253 - val_accuracy: 0.9500

# %%
score = model.evaluate_generator(test_generator)
print('Test loss : ', score[0])
print('Test accuracy : ', score[1])
# Out:
# C:\Users\ha\AppData\Local\Temp\ipykernel_12868\3196870277.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(test_generator)
# Test loss :  0.06754608452320099
# Test accuracy :  0.987500011920929

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save('final_model.h5')
# Out:
# c:\Users\ha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
